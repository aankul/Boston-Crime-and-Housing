# %%
import json
import requests
import xml.etree.ElementTree as ET
import pandas as pd
import xmltodict
import json

# %%
#Base URL
api_url = 'http://www.zillow.com/webservice/GetRegionChildren.htm?zws-id=X1-ZWz18zeeig1h57_5w3uy&state=ma&city=boston&childtype=neighborhood'

# %%
#API call
boston_house = requests.get(api_url)
boston_house
# Out:
# <Response [200]>

# %%
#Convertig XML to JSON
boston_json = xmltodict.parse(boston_house.content)
boston_json
# Out:
# OrderedDict([('RegionChildren:regionchildren',
#               OrderedDict([('@xsi:schemaLocation',
#                             'http://www.zillow.com/static/xsd/RegionChildren.xsd http://www.zillowstatic.com/vstatic/92f046f/static/xsd/RegionChildren.xsd'),
#                            ('@xmlns:xsi',
#                             'http://www.w3.org/2001/XMLSchema-instance'),
#                            ('@xmlns:RegionChildren',
#                             'http://www.zillow.com/static/xsd/RegionChildren.xsd'),
#                            ('request',
#                             OrderedDict([('state', 'ma'),
#                                          ('city', 'boston'),
#                                          ('childtype', 'neighborhood')])),
#                            ('message',
#                             OrderedDict([('text',
#                                           'Request successfully processed'),
#                                          ('code', '0')])),
#                            ('response',
#                             OrderedDict([('region',
#                                           OrderedDict([('id', '44269'),
#                                                        ('latitude',
#                                                         '42.31435'),
#                                                        ('longitude',
#                                                         '-70.970283')])),
#                                          ('subregiontype', 'neighborhood'),
#                                          ('list',
#                                           OrderedDict([('count', '31'),
#                                                        ('region',
#                                                         [OrderedDict([('id',
#                                                                        '275424'),
#                                                                       ('name',
#                                                                        'South Dorchester'),
#                                                                       ('zindex',
#                                                                        OrderedDict([('@currency',
#                                                                                      'USD'),
#                                                                                     ('#text',
#                                                                                      '360900')])),
#                                                                       ('url',
#                                                                        'http://www.zillow.com/local-info/MA-Boston/South-Dorchester/r_275424/'),
#                                                                       ('latitude',
#                                                                        '42.289714'),
#                                                                       ('longitude',
#                                                                        '-71.058369')]),
#                                                          OrderedDict([('id',
#                                                                        '54232'),
#                                                                       ('name',
#                                                                        'Roxbury'),
#                                                                       ('zindex',
#                                                                        OrderedDict([('@currency',
#                                                                                      'USD'),
#                                                                                     ('#text',
#                                                                                      '353300')])),
#                                                                       ('url',
#                                                                        'http://www.zillow.com/local-info/MA-Boston/Roxbury/r_54232/'),
#                                                                       ('latitude',
#                                                                        '42.313772'),
#                                                                       ('longitude',
#                                                                        '-71.085623')]),
#                                                          OrderedDict([('id',
#                                                                        '154399'),
#                                                                       ('name',
#                                                                        'East Boston'),
#                                                                       ('zindex',
#                                                                        OrderedDict([('@currency',
#                                                                                      'USD'),
#                                                                                     ('#text',
#                                                                                      '301500')])),
#                                                                       ('url',
#                                                                        'http://www.zillow.com/local-info/MA-Boston/East-Boston/r_154399/'),
#                                                                       ('latitude',
#                                                                        '42.372762'),
#                                                                       ('longitude',
#                                                                        '-71.015504')]),
#                                                          OrderedDict([('id',
#                                                                        '154795'),
#                                                                       ('name',
#                                                                        'Jamaica Plain'),
#                                                                       ('zindex',
#                                                                        OrderedDict([('@currency',
#                                                                                      'USD'),
#                                                                                     ('#text',
#                                                                                      '451700')])),
#                                                                       ('url',
#                                                                        'http://www.zillow.com/local-info/MA-Boston/Jamaica-Plain/r_154795/'),
#                                                                       ('latitude',
#                                                                        '42.309854'),
#                                                                       ('longitude',
#                                                                        '-71.117098')]),
#                                                          OrderedDict([('id',
#                                                                        '37575'),
#                                                                       ('name',
#                                                                        'Brighton'),
#                                                                       ('zindex',
#                                                                        OrderedDict([('@currency',
#                                                                                      'USD'),
#                                                                                     ('#text',
#                                                                                      '324300')])),
#                                                                       ('url',
#                                                                        'http://www.zillow.com/local-info/MA-Boston/Brighton/r_37575/'),
#                                                                       ('latitude',
#                                                                        '42.348503'),
#                                                                       ('longitude',
#                                                                        '-71.155063')]),
#                                                          OrderedDict([('id',
#                                                                        '154970'),
#                                                                       ('name',
#                                                                        'Mattapan'),
#                                                                       ('zindex',
#                                                                        OrderedDict([('@currency',
#                                                                                      'USD'),
#                                                                                     ('#text',
#                                                                                      '305500')])),
#                                                                       ('url',
#                                                                        'http://www.zillow.com/local-info/MA-Boston/Mattapan/r_154970/'),
#                                                                       ('latitude',
#                                                                        '42.280622'),
#                                                                       ('longitude',
#                                                                        '-71.088579')]),
#                                                          OrderedDict([('id',
#                                                                        '155633'),
#                                                                       ('name',
#                                                                        'South Boston'),
#                                                                       ('zindex',
#                                                                        OrderedDict([('@currency',
#                                                                                      'USD'),
#                                                                                     ('#text',
#                                                                                      '485400')])),
#                                                                       ('url',
#                                                                        'http://www.zillow.com/local-info/MA-Boston/South-Boston/r_155633/'),
#                                                                       ('latitude',
#                                                                        '42.338272'),
#                                                                       ('longitude',
#                                                                        '-71.037215')]),
#                                                          OrderedDict([('id',
#                                                                        '154775'),
#                                                                       ('name',
#                                                                        'Hyde Park'),
#                                                                       ('zindex',
#                                                                        OrderedDict([('@currency',
#                                                                                      'USD'),
#                                                                                     ('#text',
#                                                                                      '330200')])),
#                                                                       ('url',
#                                                                        'http://www.zillow.com/local-info/MA-Boston/Hyde-Park/r_154775/'),
#                                                                       ('latitude',
#                                                                        '42.25335'),
#                                                                       ('longitude',
#                                                                        '-71.121835')]),
#                                                          OrderedDict([('id',
#                                                                        '155506'),
#                                                                       ('name',
#                                                                        'Roslindale'),
#                                                                       ('zindex',
#                                                                        OrderedDict([('@currency',
#                                                                                      'USD'),
#                                                                                     ('#text',
#                                                                                      '394800')])),
#                                                                       ('url',
#                                                                        'http://www.zillow.com/local-info/MA-Boston/Roslindale/r_155506/'),
#                                                                       ('latitude',
#                                                                        '42.2778'),
#                                                                       ('longitude',
#                                                                        '-71.121799')]),
#                                                          OrderedDict([('id',
#                                                                        '155995'),
#                                                                       ('name',
#                                                                        'West Roxbury'),
#                                                                       ('zindex',
#                                                                        OrderedDict([('@currency',
#                                                                                      'USD'),
#                                                                                     ('#text',
#                                                                                      '460400')])),
#                                                                       ('url',
#                                                                        'http://www.zillow.com/local-info/MA-Boston/West-Roxbury/r_155995/'),
#                                                                       ('latitude',
#                                                                        '42.278343'),
#                                                                       ('longitude',
#                                                                        '-71.159316')]),
#                                                          OrderedDict([('id',
#                                                                        '275429'),
#                                                                       ('name',
#                                                                        'South End'),
#                                                                       ('zindex',
#                                                                        OrderedDict([('@currency',
#                                                                                      'USD'),
#                                                                                     ('#text',
#                                                                                      '644800')])),
#                                                                       ('url',
#                                                                        'http://www.zillow.com/local-info/MA-Boston/South-End/r_275429/'),
#                                                                       ('latitude',
#                                                                        '42.339457'),
#                                                                       ('longitude',
#                                                                        '-71.073369')]),
#                                                          OrderedDict([('id',
#                                                                        '274702'),
#                                                                       ('name',
#                                                                        'North Dorchester'),
#                                                                       ('zindex',
#                                                                        OrderedDict([('@currency',
#                                                                                      'USD'),
#                                                                                     ('#text',
#                                                                                      '347200')])),
#                                                                       ('url',
#                                                                        'http://www.zillow.com/local-info/MA-Boston/North-Dorchester/r_274702/'),
#                                                                       ('latitude',
#                                                                        '42.318295'),
#                                                                       ('longitude',
#                                                                        '-71.052347')]),
#                                                          OrderedDict([('id',
#                                                                        '272755'),
#                                                                       ('name',
#                                                                        'Allston'),
#                                                                       ('zindex',
#                                                                        OrderedDict([('@currency',
#                                                                                      'USD'),
#                                                                                     ('#text',
#                                                                                      '344400')])),
#                                                                       ('url',
#                                                                        'http://www.zillow.com/local-info/MA-Boston/Allston/r_272755/'),
#                                                                       ('latitude',
#                                                                        '42.359903'),
#                                                                       ('longitude',
#                                                                        '-71.127085')]),
#                                                          OrderedDict([('id',
#                                                                        '276331'),
#                                                                       ('name',
#                                                                        'Fenway'),
#                                                                       ('zindex',
#                                                                        OrderedDict([('@currency',
#                                                                                      'USD'),
#                                                                                     ('#text',
#                                                                                      '383300')])),
#                                                                       ('url',
#                                                                        'http://www.zillow.com/local-info/MA-Boston/Fenway/r_276331/'),
#                                                                       ('latitude',
#                                                                        '42.341237'),
#                                                                       ('longitude',
#                                                                        '-71.096193')]),
#                                                          OrderedDict([('id',
#                                                                        '272836'),
#                                                                       ('name',
#                                                                        'Back Bay'),
#                                                                       ('zindex',
#                                                                        OrderedDict([('@currency',
#                                                                                      'USD'),
#                                                                                     ('#text',
#                                                                                      '765100')])),
#                                                                       ('url',
#                                                                        'http://www.zillow.com/local-info/MA-Boston/Back-Bay/r_272836/'),
#                                                                       ('latitude',
#                                                                        '42.3492'),
#                                                                       ('longitude',
#                                                                        '-71.077257')]),
#                                                          OrderedDict([('id',
#                                                                        '154235'),
#                                                                       ('name',
#                                                                        'Charlestown'),
#                                                                       ('zindex',
#                                                                        OrderedDict([('@currency',
#                                                                                      'USD'),
#                                                                                     ('#text',
#                                                                                      '577000')])),
#                                                                       ('url',
#                                                                        'http://www.zillow.com/local-info/MA-Boston/Charlestown/r_154235/'),
#                                                                       ('latitude',
#                                                                        '42.38204'),
#                                                                       ('longitude',
#                                                                        '-71.064131')]),
#                                                          OrderedDict([('id',
#                                                                        '46015'),
#                                                                       ('name',
#                                                                        'Kenmore'),
#                                                                       ('zindex',
#                                                                        OrderedDict([('@currency',
#                                                                                      'USD'),
#                                                                                     ('#text',
#                                                                                      '401200')])),
#                                                                       ('url',
#                                                                        'http://www.zillow.com/local-info/MA-Boston/Kenmore/r_46015/'),
#                                                                       ('latitude',
#                                                                        '42.346004'),
#                                                                       ('longitude',
#                                                                        '-71.101731')]),
#                                                          OrderedDict([('id',
#                                                                        '15856'),
#                                                                       ('name',
#                                                                        'Mission Hill'),
#                                                                       ('zindex',
#                                                                        OrderedDict([('@currency',
#                                                                                      'USD'),
#                                                                                     ('#text',
#                                                                                      '398300')])),
#                                                                       ('url',
#                                                                        'http://www.zillow.com/local-info/MA-Boston/Mission-Hill/r_15856/'),
#                                                                       ('latitude',
#                                                                        '42.333347'),
#                                                                       ('longitude',
#                                                                        '-71.1015')]),
#                                                          OrderedDict([('id',
#                                                                        '155173'),
#                                                                       ('name',
#                                                                        'North End'),
#                                                                       ('zindex',
#                                                                        OrderedDict([('@currency',
#                                                                                      'USD'),
#                                                                                     ('#text',
#                                                                                      '604800')])),
#                                                                       ('url',
#                                                                        'http://www.zillow.com/local-info/MA-Boston/North-End/r_155173/'),
#                                                                       ('latitude',
#                                                                        '42.364649'),
#                                                                       ('longitude',
#                                                                        '-71.054076')]),
#                                                          OrderedDict([('id',
#                                                                        '153989'),
#                                                                       ('name',
#                                                                        'Beacon Hill'),
#                                                                       ('zindex',
#                                                                        OrderedDict([('@currency',
#                                                                                      'USD'),
#                                                                                     ('#text',
#                                                                                      '645100')])),
#                                                                       ('url',
#                                                                        'http://www.zillow.com/local-info/MA-Boston/Beacon-Hill/r_153989/'),
#                                                                       ('latitude',
#                                                                        '42.35837'),
#                                                                       ('longitude',
#                                                                        '-71.067219')]),
#                                                          OrderedDict([('id',
#                                                                        '416396'),
#                                                                       ('name',
#                                                                        'Chinatown'),
#                                                                       ('zindex',
#                                                                        OrderedDict([('@currency',
#                                                                                      'USD'),
#                                                                                     ('#text',
#                                                                                      '830900')])),
#                                                                       ('url',
#                                                                        'http://www.zillow.com/local-info/MA-Boston/Chinatown/r_416396/'),
#                                                                       ('latitude',
#                                                                        '42.350936'),
#                                                                       ('longitude',
#                                                                        '-71.061934')]),
#                                                          OrderedDict([('id',
#                                                                        '273181'),
#                                                                       ('name',
#                                                                        'West End'),
#                                                                       ('url',
#                                                                        'http://www.zillow.com/local-info/MA-Boston/West-End/r_273181/'),
#                                                                       ('latitude',
#                                                                        '42.365039'),
#                                                                       ('longitude',
#                                                                        '-71.065091')]),
#                                                          OrderedDict([('id',
#                                                                        '270824'),
#                                                                       ('name',
#                                                                        'Downtown'),
#                                                                       ('zindex',
#                                                                        OrderedDict([('@currency',
#                                                                                      'USD'),
#                                                                                     ('#text',
#                                                                                      '828100')])),
#                                                                       ('url',
#                                                                        'http://www.zillow.com/local-info/MA-Boston/Downtown/r_270824/'),
#                                                                       ('latitude',
#                                                                        '42.353186'),
#                                                                       ('longitude',
#                                                                        '-71.054584')]),
#                                                          OrderedDict([('id',
#                                                                        '153980'),
#                                                                       ('name',
#                                                                        'Bay Village'),
#                                                                       ('url',
#                                                                        'http://www.zillow.com/local-info/MA-Boston/Bay-Village/r_153980/'),
#                                                                       ('latitude',
#                                                                        '42.349983'),
#                                                                       ('longitude',
#                                                                        '-71.068688')]),
#                                                          OrderedDict([('id',
#                                                                        '11842'),
#                                                                       ('name',
#                                                                        'Haymarket'),
#                                                                       ('url',
#                                                                        'http://www.zillow.com/local-info/MA-Boston/Haymarket/r_11842/'),
#                                                                       ('latitude',
#                                                                        '42.360987'),
#                                                                       ('longitude',
#                                                                        '-71.055304')]),
#                                                          OrderedDict([('id',
#                                                                        '154380'),
#                                                                       ('name',
#                                                                        'Downtown Crossing'),
#                                                                       ('url',
#                                                                        'http://www.zillow.com/local-info/MA-Boston/Downtown-Crossing/r_154380/'),
#                                                                       ('latitude',
#                                                                        '42.35477'),
#                                                                       ('longitude',
#                                                                        '-71.060369')]),
#                                                          OrderedDict([('id',
#                                                                        '416395'),
#                                                                       ('name',
#                                                                        'Government Center'),
#                                                                       ('url',
#                                                                        'http://www.zillow.com/local-info/MA-Boston/Government-Center/r_416395/'),
#                                                                       ('latitude',
#                                                                        '42.36068'),
#                                                                       ('longitude',
#                                                                        '-71.059013')]),
#                                                          OrderedDict([('id',
#                                                                        '269750'),
#                                                                       ('name',
#                                                                        'Leather District'),
#                                                                       ('url',
#                                                                        'http://www.zillow.com/local-info/MA-Boston/Leather-District/r_269750/'),
#                                                                       ('latitude',
#                                                                        '42.35089'),
#                                                                       ('longitude',
#                                                                        '-71.057834')]),
#                                                          OrderedDict([('id',
#                                                                        '403114'),
#                                                                       ('name',
#                                                                        'Long Island'),
#                                                                       ('url',
#                                                                        'http://www.zillow.com/local-info/MA-Boston/Long-Island/r_403114/'),
#                                                                       ('latitude',
#                                                                        '42.320645'),
#                                                                       ('longitude',
#                                                                        '-70.965403')])])]))]))]))])

# %%
#Adding json data to data frame
rows_list = []

for i in boston_json['RegionChildren:regionchildren']['response']['list']['region']:
    if(i.get('zindex') is not None) :
        zillow = {}
        zillow['District'] = i.get('name')
        zillow['Price'] = i.get('zindex').get('#text')
        zillow['latitude'] = i.get('latitude')
        zillow['longitude'] = i.get('longitude')  
        rows_list.append(zillow)
df_boston_house = pd.DataFrame(rows_list)  
df_boston_house
# Out:
#             District   Price   latitude   longitude
# 0   South Dorchester  360900  42.289714  -71.058369
# 1            Roxbury  353300  42.313772  -71.085623
# 2        East Boston  301500  42.372762  -71.015504
# 3      Jamaica Plain  451700  42.309854  -71.117098
# 4           Brighton  324300  42.348503  -71.155063
# 5           Mattapan  305500  42.280622  -71.088579
# 6       South Boston  485400  42.338272  -71.037215
# 7          Hyde Park  330200   42.25335  -71.121835
# 8         Roslindale  394800    42.2778  -71.121799
# 9       West Roxbury  460400  42.278343  -71.159316
# 10         South End  644800  42.339457  -71.073369
# 11  North Dorchester  347200  42.318295  -71.052347
# 12           Allston  344400  42.359903  -71.127085
# 13            Fenway  383300  42.341237  -71.096193
# 14          Back Bay  765100    42.3492  -71.077257
# 15       Charlestown  577000   42.38204  -71.064131
# 16           Kenmore  401200  42.346004  -71.101731
# 17      Mission Hill  398300  42.333347    -71.1015
# 18         North End  604800  42.364649  -71.054076
# 19       Beacon Hill  645100   42.35837  -71.067219
# 20         Chinatown  830900  42.350936  -71.061934
# 21          Downtown  828100  42.353186  -71.054584

# %%
#Writing it into csv
df_boston_house.to_csv('boston_house_price_current.csv')
